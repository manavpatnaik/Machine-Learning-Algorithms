# %% [markdown]
# # Logistic Regression
#
# ## A classification algorithm
#
# Predicting a **Categorical Label** based on historical feature data
#
# - ### Discretization:
# Any continuous target can be converted into categories using **Discretization**
# House Prices:
# 1. Class 0 - 10K to 50K
# 2. Class 1 - 50K to 100K
# 3. Class 2 - 100K to 150K
#
# - ### Classification algos often produce probability of prediction
# 1. Class 0 - 90%
# 2. Class 1 - 5%
# 3. Class 2 - 21%
#
# Here usual metrics like MAE, MSE, RMSE will not work. New set of error metrics required

# %% [markdown]
# ## The Logistic Function
#
# - Transforms linear regression to logistic regression
# - Using a sigmoid function
# - O/P always between 0 and 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How to convert Linear Regr. to Logistic Regr. model
#
# Consider the dataset
# ![image.png](attachment:image.png)
#
# Lets plot it:
# ![image-2.png](attachment:image-2.png)
#
# **Fitting a Linear Regression to model it will not work**
#
# ### Using logistic regression
# ![image-3.png](attachment:image-3.png)
#
# - We define a threshold point, y=0.5
# - y axis is treated as probability

# %% [markdown]
# ## How to draw that Logistic regression line?
#
# Pass the linear regression line to the logistic function
#
# > Linear regression: ![image.png](attachment:image.png)
#
# > Logistic function: ![image-2.png](attachment:image-2.png)
#
# Passing the linear regrssion into the logistic function
#
# > ![image-3.png](attachment:image-3.png)
#
# ### Solving for log odds
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# - +ve Beta coefficients indicate an increase in likelihood of belonging to 1 class
# - -ve Beta coefficients indicate a decrease in likelihood of belonging to 2 class

# %% [markdown]
# ## How to fit the best fitting logistic regression curve?
#
# Uses **Maximum Likelihood** method
#
# ### The cost function we need to minimize
# ![image.png](attachment:image.png)

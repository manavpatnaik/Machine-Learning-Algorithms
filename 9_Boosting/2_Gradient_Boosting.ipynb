# %% [markdown]
# # Gradient Boosting
#
# Very similar to AdaBoost
#
# - Here we allow larger decision trees to be developed rather than the stumps developed in AdaBoost
# - Learning rate is same for all weak learners
# - Gradual series learning is based on training on the residuals of the previous model
#
# Consider the dataset
# ![image.png](attachment:image.png)
#
# We train a decision tree based on this dataset
# ![image-2.png](attachment:image-2.png)
#
# It may not perform very well
#
# We take the predictions and calculate the residuals
#
# - resudial = y - y_hat
#
# ![image-3.png](attachment:image-3.png)
#
# - This residual term now has info of the model
#
# Now, in Gradient Boosting, we try to predict the **error**
# ![image-4.png](attachment:image-4.png)
#
# Now update predictions using **error**:
# ![image-5.png](attachment:image-5.png)
#
# The formula is basically:
# ![image-6.png](attachment:image-6.png)
#
#
# ## The process:
#
# - Create initial model: f<sub>0</sub>
# - Train model on error
# - e = y - f0
# - Create new Prediction
# ![image-7.png](attachment:image-7.png)
# - Repeat
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# # Ridge Regression (L2 Regularization)
#
# A **refularization technique** that helps reduce the potential for overfitting by adding a **penalty term** to error that is based on squared value of coefficients

# %% [markdown]
# ## Linear Regression Line
#
# The general formula for regression line looks like:
#
# ![image.png](attachment:image.png)
#
# The coefficients were solved by minimizing the **Sum of Squares**
#
# ![image-2.png](attachment:image-2.png)
#
# Substituting for y hat
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Ridge Regression penalty term
#
# ![image.png](attachment:image.png)
#
# - This term is also called **Shrinkage penalty**
#
# - That lambda parameter is tunable.
#
# - And the square of beta coefficient is considered

# %% [markdown]
# If the slope is large, then it is punished equally large.
#
# i.e It lowers the slope
#
# We are trying to increase bias slightly to decrease variance
#
# - RED line - Reg. Line for Training data
#
# - BLUE line - Penalized line, ridge regression line (slope is decreased)
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Note:
#
# > Scikit learn calls that tunable paramerter lambda as **alpha**
